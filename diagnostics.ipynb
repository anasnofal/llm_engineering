# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Rhen email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Starting diagnostics at 2025-09-14 16:04:29
#
# ===== System Information =====
# Operating System: Darwin
# MacOS Version: 14.5
# Architecture: ('64bit', '')
# Machine: arm64
# Processor: arm
# Total RAM: 16.00 GB
# Available RAM: 4.51 GB
# Free Disk Space: 45.22 GB
#
# ===== File System Information =====
# Current Directory: /Users/anas/PythonProjects/llm_engineering
# Write permission: OK
#
# Files in Current Directory:
#  - .env
#  - .git
#  - .gitignore
#  - LICENSE
#  - README.md
#  - SETUP-PC.md
#  - SETUP-PC.pdf
#  - SETUP-linux.md
#  - SETUP-linux.pdf
#  - SETUP-mac.md
#  - SETUP-mac.pdf
#  - __pycache__
#  - business.jpg
#  - community-contributions
#  - diagnostics.ipynb
#  - diagnostics.py
#  - environment.yml
#  - extras
#  - important.jpg
#  - llms
#  - report.txt
#  - requirements.txt
#  - resources.jpg
#  - thankyou.jpg
#  - voyage.jpg
#  - week1
#  - week2
#  - week3
#  - week4
#  - week5
#  - week6
#  - week7
#  - week8
#
# ===== Git Repository Information =====
# Git Repository Root: /Users/anas/PythonProjects/llm_engineering
# Current Commit: 236749eb29ce3f422370679c3754a3873e42ead8
# Remote Origin: https://github.com/anasnofal/llm_engineering.git
#
# ===== Environment File Check =====
# .env file exists at: /Users/anas/PythonProjects/llm_engineering/.env
# WARNING: OPENAI_API_KEY not found in .env file
#
# ===== Anaconda Environment Check =====
# No active Anaconda environment detected
#
# ===== Virtualenv Check =====
# Virtualenv is active:
# Environment Path: /Users/anas/PythonProjects/llm_engineering/llms
# Environment Name: llms
#
# Python Environment:
# Python Version: 3.11.12 (main, Apr  8 2025, 14:15:29) [Clang 16.0.0 (clang-1600.0.26.6)]
# Python Executable: /Users/anas/PythonProjects/llm_engineering/llms/bin/python
#
# Required Package Versions:
# ERROR: Required package 'openai' is not installed
# ERROR: Required package 'python-dotenv' is not installed
# requests: 2.32.5
# ERROR: Required package 'gradio' is not installed
# ERROR: Required package 'transformers' is not installed
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.5.2 5 Aug 2025
# ✓ Connected to https://www.google.com
#   Response time: 0.11s
#
# Performing bandwidth test using speedtest-cli...
# ERROR: Failed to retrieve speedtest configuration
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python311.zip
#  - /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11
#  - /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload
#  -
#  - /Users/anas/PythonProjects/llm_engineering/llms/lib/python3.11/site-packages
#  - /Users/anas/PythonProjects/llm_engineering/llms/lib/python3.11/site-packages/setuptools/_vendor
# ERROR: Environment variables check failed: No module named 'dotenv'
#
# ===== Additional Diagnostics =====
# Temp directory is writable: /var/folders/tg/jhy0d12925ldvjghgc440mjh0000gn/T
#
# ===== Warnings Found =====
# The following warnings were detected. They might not prevent the program from running but could cause unexpected behavior:
# - OPENAI_API_KEY not found in .env file
#
# ===== Errors Found =====
# The following critical issues were detected. Please address them before proceeding:
# - Required package 'openai' is not installed
# - Required package 'python-dotenv' is not installed
# - Required package 'gradio' is not installed
# - Required package 'transformers' is not installed
# - Failed to retrieve speedtest configuration
# - Environment variables check failed: No module named 'dotenv'
#
#
# Completed diagnostics at 2025-09-14 16:04:30
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
